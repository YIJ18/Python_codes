# %%
import pandas as pd

# %%
pd.__version__
# Out:
# '2.2.2'

# %%
data=pd.read_csv("olympics.csv", skiprows=4)

# %%
data.head()
# Out:
#      City  Edition     Sport Discipline             Athlete  NOC Gender  \
# 0  Athens     1896  Aquatics   Swimming       HAJOS, Alfred  HUN    Men
# 1  Athens     1896  Aquatics   Swimming    HERSCHMANN, Otto  AUT    Men
# 2  Athens     1896  Aquatics   Swimming   DRIVAS, Dimitrios  GRE    Men
# 3  Athens     1896  Aquatics   Swimming  MALOKINIS, Ioannis  GRE    Men
# 4  Athens     1896  Aquatics   Swimming  CHASAPIS, Spiridon  GRE    Men
#
#                         Event Event_gender   Medal
# 0              100m freestyle            M    Gold
# 1              100m freestyle            M  Silver
# 2  100m freestyle for sailors            M  Bronze
# 3  100m freestyle for sailors            M    Gold
# 4  100m freestyle for sailors            M  Silver

# %%
data['Sport']
# Out:
# 0         Aquatics
# 1         Aquatics
# 2         Aquatics
# 3         Aquatics
# 4         Aquatics
#            ...
# 29211    Wrestling
# 29212    Wrestling
# 29213    Wrestling
# 29214    Wrestling
# 29215    Wrestling
# Name: Sport, Length: 29216, dtype: object

# %%
data['Medal']
# Out:
# 0          Gold
# 1        Silver
# 2        Bronze
# 3          Gold
# 4        Silver
#           ...
# 29211    Silver
# 29212    Bronze
# 29213    Bronze
# 29214      Gold
# 29215    Silver
# Name: Medal, Length: 29216, dtype: object

# %%
data['NOC']
# Out:
# 0        HUN
# 1        AUT
# 2        GRE
# 3        GRE
# 4        GRE
#         ...
# 29211    GER
# 29212    LTU
# 29213    ARM
# 29214    CUB
# 29215    RUS
# Name: NOC, Length: 29216, dtype: object

# %%
data.shape
# Out:
# (29216, 10)

# %%
filas, columnas = data.shape

# %%
filas
# Out:
# 29216

# %%
columnas
# Out:
# 10

# %%
data.Medal
# Out:
# 0          Gold
# 1        Silver
# 2        Bronze
# 3          Gold
# 4        Silver
#           ...
# 29211    Silver
# 29212    Bronze
# 29213    Bronze
# 29214      Gold
# 29215    Silver
# Name: Medal, Length: 29216, dtype: object

# %%
data.head
# Out:
# <bound method NDFrame.head of           City  Edition      Sport       Discipline               Athlete  \
# 0       Athens     1896   Aquatics         Swimming         HAJOS, Alfred
# 1       Athens     1896   Aquatics         Swimming      HERSCHMANN, Otto
# 2       Athens     1896   Aquatics         Swimming     DRIVAS, Dimitrios
# 3       Athens     1896   Aquatics         Swimming    MALOKINIS, Ioannis
# 4       Athens     1896   Aquatics         Swimming    CHASAPIS, Spiridon
# ...        ...      ...        ...              ...                   ...
# 29211  Beijing     2008  Wrestling  Wrestling Gre-R        ENGLICH, Mirko
# 29212  Beijing     2008  Wrestling  Wrestling Gre-R  MIZGAITIS, Mindaugas
# 29213  Beijing     2008  Wrestling  Wrestling Gre-R       PATRIKEEV, Yuri
# 29214  Beijing     2008  Wrestling  Wrestling Gre-R         LOPEZ, Mijain
# 29215  Beijing     2008  Wrestling  Wrestling Gre-R        BAROEV, Khasan
#
# ...

# %%
data.head(5)
# Out:
#      City  Edition     Sport Discipline             Athlete  NOC Gender  \
# 0  Athens     1896  Aquatics   Swimming       HAJOS, Alfred  HUN    Men
# 1  Athens     1896  Aquatics   Swimming    HERSCHMANN, Otto  AUT    Men
# 2  Athens     1896  Aquatics   Swimming   DRIVAS, Dimitrios  GRE    Men
# 3  Athens     1896  Aquatics   Swimming  MALOKINIS, Ioannis  GRE    Men
# 4  Athens     1896  Aquatics   Swimming  CHASAPIS, Spiridon  GRE    Men
#
#                         Event Event_gender   Medal
# 0              100m freestyle            M    Gold
# 1              100m freestyle            M  Silver
# 2  100m freestyle for sailors            M  Bronze
# 3  100m freestyle for sailors            M    Gold
# 4  100m freestyle for sailors            M  Silver

# %%
data.tail(3)
# Out:
#           City  Edition      Sport       Discipline          Athlete  NOC  \
# 29213  Beijing     2008  Wrestling  Wrestling Gre-R  PATRIKEEV, Yuri  ARM
# 29214  Beijing     2008  Wrestling  Wrestling Gre-R    LOPEZ, Mijain  CUB
# 29215  Beijing     2008  Wrestling  Wrestling Gre-R   BAROEV, Khasan  RUS
#
#       Gender       Event Event_gender   Medal
# 29213    Men  96 - 120kg            M  Bronze
# 29214    Men  96 - 120kg            M    Gold
# 29215    Men  96 - 120kg            M  Silver

# %%
data['Medal']
# Out:
# 0          Gold
# 1        Silver
# 2        Bronze
# 3          Gold
# 4        Silver
#           ...
# 29211    Silver
# 29212    Bronze
# 29213    Bronze
# 29214      Gold
# 29215    Silver
# Name: Medal, Length: 29216, dtype: object

# %%
data['Medal'].unique()
# Out:
# array(['Gold', 'Silver', 'Bronze'], dtype=object)

# %%
data["City"]
# Out:
# 0         Athens
# 1         Athens
# 2         Athens
# 3         Athens
# 4         Athens
#           ...
# 29211    Beijing
# 29212    Beijing
# 29213    Beijing
# 29214    Beijing
# 29215    Beijing
# Name: City, Length: 29216, dtype: object

# %%
data['City'].unique()
# Out:
# array(['Athens', 'Paris', 'St Louis', 'London', 'Stockholm', 'Antwerp',
#        'Amsterdam', 'Los Angeles', 'Berlin', 'Helsinki',
#        'Melbourne / Stockholm', 'Rome', 'Tokyo', 'Mexico', 'Munich',
#        'Montreal', 'Moscow', 'Seoul', 'Barcelona', 'Atlanta', 'Sydney',
#        'Beijing'], dtype=object)

# %%
data['Medal'].value_counts()
# Out:
# Medal
# Gold      9850
# Bronze    9689
# Silver    9677
# Name: count, dtype: int64

# %%
data['City'].sort_values()
# Out:
# 5177     Amsterdam
# 5398     Amsterdam
# 5399     Amsterdam
# 5400     Amsterdam
# 5401     Amsterdam
#            ...
# 10737        Tokyo
# 10736        Tokyo
# 10735        Tokyo
# 10748        Tokyo
# 11623        Tokyo
# Name: City, Length: 29216, dtype: object

# %%
data[data['NOC']=="MEX"].value_counts()
# Out:
# City      Edition  Sport       Discipline     Athlete                 NOC  Gender  Event                      Event_gender  Medal
# Athens    2004     Athletics   Athletics      GUEVARA, Ana            MEX  Women   400m                       W             Silver    1
#                    Cycling     Cycling Track  GUERRERO MENDEZ, Belem  MEX  Women   points race                W             Silver    1
# Moscow    1980     Equestrian  Eventing       BARCENA RIOS, David     MEX  Men     team                       X             Bronze    1
#                    Aquatics    Diving         GIRON, Carlos           MEX  Men     3m springboard             M             Silver    1
# Montreal  1976     Boxing      Boxing         PAREDES, Juan           MEX  Men     54 - 57kg (featherweight)  M             Bronze    1
#                                                                                                                                      ..
# ...

# %%
data[(data['Medal']=="Bronze") & (data["Gender"]=="Men")]
# Out:
#           City  Edition      Sport       Discipline                Athlete  \
# 2       Athens     1896   Aquatics         Swimming      DRIVAS, Dimitrios
# 5       Athens     1896   Aquatics         Swimming  CHOROPHAS, Efstathios
# 8       Athens     1896   Aquatics         Swimming  CHOROPHAS, Efstathios
# 11      Athens     1896  Athletics        Athletics          LANE, Francis
# 12      Athens     1896  Athletics        Athletics       SZOKOLYI, Alajos
# ...        ...      ...        ...              ...                    ...
# 29205  Beijing     2008  Wrestling  Wrestling Gre-R          AVLUCA, Nazmi
# 29208  Beijing     2008  Wrestling  Wrestling Gre-R        MAMBETOV, Asset
# 29209  Beijing     2008  Wrestling  Wrestling Gre-R          WHEELER, Adam
# 29212  Beijing     2008  Wrestling  Wrestling Gre-R   MIZGAITIS, Mindaugas
# 29213  Beijing     2008  Wrestling  Wrestling Gre-R        PATRIKEEV, Yuri
#
#        NOC Gender                       Event Event_gender   Medal
# ...

# %%
data[(data['NOC']=="MEX") & (data["Medal"]=="Gold")].count()
# Out:
# City            14
# Edition         14
# Sport           14
# Discipline      14
# Athlete         14
# NOC             14
# Gender          14
# Event           14
# Event_gender    14
# Medal           14
# dtype: int64

# %%
data[data["Athlete"].str.contains("Jose")]
# Out:
#            City  Edition          Sport       Discipline  \
# 281       Paris     1900      Athletics        Athletics
# 285       Paris     1900      Athletics        Athletics
# 513       Paris     1900          Rugby            Rugby
# 661       Paris     1900     Tug of War       Tug of War
# 695    St Louis     1904       Aquatics         Swimming
# ...         ...      ...            ...              ...
# 27842   Beijing     2008     Basketball       Basketball
# 27960   Beijing     2008  Canoe / Kayak  Canoe / Kayak F
# 28134   Beijing     2008        Fencing          Fencing
# 28230   Beijing     2008       Football         Football
# 28410   Beijing     2008       Handball         Handball
#
#                       Athlete  NOC Gender                    Event  \
# 281     LEAHY, Patrick Joseph  GBR    Men                high jump
# 285     LEAHY, Patrick Joseph  GBR    Men                long jump
# 513           OLIVIER, Joseph  FRA    Men                    rugby
# ...

# %%
data[(data['NOC']=="MEX") & (data["Medal"]=="Silver")].count()
# Out:
# City            18
# Edition         18
# Sport           18
# Discipline      18
# Athlete         18
# NOC             18
# Gender          18
# Event           18
# Event_gender    18
# Medal           18
# dtype: int64

# %%
data[(data['NOC']=="MEX") & (data["Medal"]=="Silver")]
# Out:
#               City  Edition       Sport       Discipline  \
# 5918   Los Angeles     1932      Boxing           Boxing
# 6271   Los Angeles     1932    Shooting         Shooting
# 7586        London     1948  Equestrian          Jumping
# 8020      Helsinki     1952    Aquatics           Diving
# 11686       Mexico     1968    Aquatics           Diving
# 11884       Mexico     1968   Athletics        Athletics
# 12216       Mexico     1968     Fencing          Fencing
# 13099       Munich     1972      Boxing           Boxing
# 15213       Moscow     1980    Aquatics           Diving
# 16820  Los Angeles     1984   Athletics        Athletics
# 17038  Los Angeles     1984      Boxing           Boxing
# 18029  Los Angeles     1984   Wrestling  Wrestling Gre-R
# 19967    Barcelona     1992   Athletics        Athletics
# 23169       Sydney     2000    Aquatics           Diving
# 23549       Sydney     2000   Athletics        Athletics
# ...

# %%
data[(data['Medal']=="Gold") & (data["Gender"]=="Women")]
# Out:
#            City  Edition          Sport       Discipline  \
# 417       Paris     1900           Golf             Golf
# 641       Paris     1900         Tennis           Tennis
# 649       Paris     1900         Tennis           Tennis
# 710    St Louis     1904        Archery          Archery
# 713    St Louis     1904        Archery          Archery
# ...         ...      ...            ...              ...
# 29134   Beijing     2008  Weightlifting    Weightlifting
# 29147   Beijing     2008      Wrestling  Wrestling Free.
# 29155   Beijing     2008      Wrestling  Wrestling Free.
# 29163   Beijing     2008      Wrestling  Wrestling Free.
# 29171   Beijing     2008      Wrestling  Wrestling Free.
#
#                      Athlete  NOC Gender  \
# 417    ABBOTT, Margaret Ives  USA  Women
# 641        COOPER, Charlotte  GBR  Women
# 649        COOPER, Charlotte  GBR  Women
# 710    HOWELL, Matilda Scott  USA  Women
# 713    HOWELL, Matilda Scott  USA  Women
# ...

# %%
data[(data['Medal']=="Gold") & (data["Gender"]=="Women")].count()
# Out:
# City            2485
# Edition         2485
# Sport           2485
# Discipline      2485
# Athlete         2485
# NOC             2485
# Gender          2485
# Event           2485
# Event_gender    2485
# Medal           2485
# dtype: int64

# %%
data[(data['Medal']=="Silver") & (data["Gender"]=="Women") & (data["Sport"]=="Tennis")].count()
# Out:
# City            32
# Edition         32
# Sport           32
# Discipline      32
# Athlete         32
# NOC             32
# Gender          32
# Event           32
# Event_gender    32
# Medal           32
# dtype: int64

# %%
import matplotlib

# %%
data['Sport'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Sport'>

# %%
data[(data['Medal']=="Silver") & (data["Gender"]=="Women") & (data["Sport"]=="Tennis")]
# Out:
#             City  Edition   Sport Discipline  \
# 642        Paris     1900  Tennis     Tennis
# 650        Paris     1900  Tennis     Tennis
# 1871      London     1908  Tennis     Tennis
# 1877      London     1908  Tennis     Tennis
# 2772   Stockholm     1912  Tennis     Tennis
# 2778   Stockholm     1912  Tennis     Tennis
# 2784   Stockholm     1912  Tennis     Tennis
# 2790   Stockholm     1912  Tennis     Tennis
# 4036     Antwerp     1920  Tennis     Tennis
# 4037     Antwerp     1920  Tennis     Tennis
# 4043     Antwerp     1920  Tennis     Tennis
# 4049     Antwerp     1920  Tennis     Tennis
# 4936       Paris     1924  Tennis     Tennis
# 4937       Paris     1924  Tennis     Tennis
# 4943       Paris     1924  Tennis     Tennis
# 4949       Paris     1924  Tennis     Tennis
# 19425      Seoul     1988  Tennis     Tennis
# 19426      Seoul     1988  Tennis     Tennis
# 19434      Seoul     1988  Tennis     Tennis
# 21131  Barcelona     1992  Tennis     Tennis
# ...

# %%
data['Sport'].value_counts().plot(kind='pie')
# Out:
# <Axes: ylabel='count'>

# %%
data['Sport'].value_counts().plot(kind='violinplot')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[167], line 1
# ----> 1 data['Sport'].value_counts().plot(kind='violinplot')
#
# File /opt/anaconda3/lib/python3.12/site-packages/pandas/plotting/_core.py:960, in PlotAccessor.__call__(self, *args, **kwargs)
#     957     return plot_backend.plot(self._parent, x=x, y=y, kind=kind, **kwargs)
#     959 if kind not in self._all_kinds:
# --> 960     raise ValueError(
#     961         f"{kind} is not a valid plot kind "
#     962         f"Valid plot kinds: {self._all_kinds}"
#     963     )
#     965 # The original data structured can be transformed before passed to the
#     966 # backend. For example, for DataFrame is common to set the index as the
#     967 # `x` parameter, and return a Series with the parameter `y` as values.
#     968 data = self._parent.copy()
#
# ...

# %%
import seaborn as sns

# %%
sns.violinplot(y='Sport', data=data)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[175], line 2
#       1 sns.violinplot(y='Sport', data=data)
# ----> 2 plt.show()
#
# NameError: name 'plt' is not defined
